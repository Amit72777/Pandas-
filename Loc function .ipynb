# %%
import pandas as pd

# %%
m_data = pd.read_csv("tmdb_5000_movies.csv")

# %%
m_data.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
m_data.loc[0] # informatin about 1st row
# Out:
# budget                                                          237000000
# genres                  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# homepage                                      http://www.avatarmovie.com/
# id                                                                  19995
# keywords                [{"id": 1463, "name": "culture clash"}, {"id":...
# original_language                                                      en
# original_title                                                     Avatar
# overview                In the 22nd century, a paraplegic Marine is di...
# popularity                                                     150.437577
# production_companies    [{"name": "Ingenious Film Partners", "id": 289...
# production_countries    [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                   2009-12-10
# revenue                                                        2787965087
# ...

# %%
m_data.loc[0:3] # informatio about 0 to 3rd row
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
#
# ...

# %%
movie_data = pd.read_csv("tmdb_5000_movies.csv",index_col = "original_title")

# %%
movie_data
# Out:
#                                              budget  \
# original_title
# Avatar                                    237000000
# Pirates of the Caribbean: At World's End  300000000
# Spectre                                   245000000
# The Dark Knight Rises                     250000000
# John Carter                               260000000
# ...                                             ...
# El Mariachi                                  220000
# Newlyweds                                      9000
# Signed, Sealed, Delivered                         0
# Shanghai Calling                                  0
# My Date with Drew                                 0
#
#                                                                                      genres  \
# original_title
# Avatar                                    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# Pirates of the Caribbean: At World's End  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# ...

# %%
movie_data.loc["My Date with Drew"] # using index name solve data for single row
# Out:
# budget                                                                  0
# genres                                [{"id": 99, "name": "Documentary"}]
# homepage                                                              NaN
# id                                                                  25975
# keywords                [{"id": 1523, "name": "obsession"}, {"id": 224...
# original_language                                                      en
# overview                Ever since the second grade when he first saw ...
# popularity                                                       1.929883
# production_companies    [{"name": "rusty bear entertainment", "id": 87...
# production_countries    [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                   2005-08-05
# revenue                                                                 0
# runtime                                                              90.0
# ...

# %%
movie_data.loc[["My Date with Drew",'Spectre', "Avatar"]] # using index name solve data for multiple row
# Out:
#                       budget  \
# original_title
# My Date with Drew          0
# Spectre            245000000
# Avatar             237000000
#
#                                                               genres  \
# original_title
# My Date with Drew                [{"id": 99, "name": "Documentary"}]
# Spectre            [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# Avatar             [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                                       homepage      id  \
# original_title
# My Date with Drew                                          NaN   25975
# Spectre            http://www.sonypictures.com/movies/spectre/  206647
# Avatar                             http://www.avatarmovie.com/   19995
#
#                                                             keywords  \
# original_title
# My Date with Drew  [{"id": 1523, "name": "obsession"}, {"id": 224...
# Spectre            [{"id": 470, "name": "spy"}, {"id": 818, "name...
# ...

# %%
movie_data.loc[["My Date with Drew",'Spectre', "Avatar"],["id",'homepage','keywords']] # fo Multiple row and selective column
# Out:
#                        id                                     homepage  \
# original_title
# My Date with Drew   25975                                          NaN
# Spectre            206647  http://www.sonypictures.com/movies/spectre/
# Avatar              19995                  http://www.avatarmovie.com/
#
#                                                             keywords
# original_title
# My Date with Drew  [{"id": 1523, "name": "obsession"}, {"id": 224...
# Spectre            [{"id": 470, "name": "spy"}, {"id": 818, "name...
# Avatar             [{"id": 1463, "name": "culture clash"}, {"id":...

# %%
movie_data.id
# Out:
# original_title
# Avatar                                       19995
# Pirates of the Caribbean: At World's End       285
# Spectre                                     206647
# The Dark Knight Rises                        49026
# John Carter                                  49529
#                                              ...
# El Mariachi                                   9367
# Newlyweds                                    72766
# Signed, Sealed, Delivered                   231617
# Shanghai Calling                            126186
# My Date with Drew                            25975
# Name: id, Length: 4803, dtype: int64
